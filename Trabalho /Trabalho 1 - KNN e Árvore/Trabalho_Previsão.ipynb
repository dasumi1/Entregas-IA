# %%
import pandas as pd

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

SHEET_ID = "1gak9eqEBcgFOzP1uPjVi__X3tfKDdEFec77nUFLcWpc"
GID = "822446140"  # aba Página1
url_tsv = f"https://docs.google.com/spreadsheets/d/{SHEET_ID}/export?format=tsv&gid={GID}"

# TSV + vírgula decimal
df = pd.read_csv(url_tsv, sep="\t", decimal=",")

print("Colunas lidas:", list(df.columns))
display(df.head())
# Out:
# Colunas lidas: ['Country', 'Region', 'Happiness Rank', 'Happiness Score', 'Lower Confidence Interval', 'Upper Confidence Interval', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual', 'Happiness_Class']
#        Country          Region  Happiness Rank Happiness Score  \
# 0      Denmark  Western Europe               1           7.526
# 1  Switzerland  Western Europe               2           7.509
# 2      Iceland  Western Europe               3           7.501
# 3       Norway  Western Europe               4           7.498
# 4      Finland  Western Europe               5           7.413
#
#   Lower Confidence Interval Upper Confidence Interval  \
# 0                      7.46                     7.592
# 1                     7.428                      7.59
# 2                     7.333                     7.669
# 3                     7.421                     7.575
# 4                     7.351                     7.475
#
#   Economy (GDP per Capita)   Family Health (Life Expectancy) Freedom  \
# 0                  144.178  116.374                   79.504  57.941
# 1                  152.733  114.524                   86.303  58.557
# 2                  142.666  118.326                   86.733  56.624
# 3                  157.744   1.1269                   79.579  59.609
# 4                  140.598  113.464                   81.091  57.104
#
#   Trust (Government Corruption) Generosity Dystopia Residual Happiness_Class
# 0                        44.453     36.171           273.939            Alto
# 1                        41.203     28.083           269.463            Alto
# 2                        14.975     47.678           283.137            Alto
# 3                        35.776     37.895           266.465            Alto
# 4                        41.004     25.492           282.596            Alto

# %%
#FEATURES = ["Economy (GDP per Capita)", "Health (Life Expectancy)", "Freedom"]
FEATURE_SETS = {
    "BC":  ["Economy (GDP per Capita)", "Health (Life Expectancy)"],              # colunas B,C
    "BD":  ["Economy (GDP per Capita)", "Freedom"],             # colunas B,D
    "CD":  ["Health (Life Expectancy)", "Freedom"],            # colunas C,D
    "BCD": ["Economy (GDP per Capita)", "Health (Life Expectancy)", "Freedom"] # colunas B,C,D
}
FEATURES = FEATURE_SETS["BC"]   # <-- troque aqui: "BC", "BD", "CD", "BCD"

TARGET = "Happiness_Class"            # coluna N (classe)

for col in FEATURES + ["Happiness Rank"]:
    df[col] = pd.to_numeric(df[col], errors="coerce")

# Normaliza o target e remove linhas inválidas
df[TARGET] = df[TARGET].astype(str).str.strip().str.lower()
df = df.dropna(subset=FEATURES + [TARGET]).copy() #remove linhas com valores inválidos

print("\nDistribuição do target:")
print(df[TARGET].value_counts())
# Out:
# Distribuição do target:
# Happiness_Class
# baixo    58
# medio    52
# alto     47
# Name: count, dtype: int64

# %%
le = LabelEncoder()
y_all = le.fit_transform(df[TARGET])
X_all = df[FEATURES].values

print("\nClasses:", list(le.classes_))
print("Total linhas válidas:", len(df))
# Out:
# Classes: ['alto', 'baixo', 'medio']
# Total linhas válidas: 157

# %%
RANDOM_STATE = 42
df_shuffled = df.sample(frac=1, random_state=RANDOM_STATE).reset_index(drop=True)
limite_teste=int(len(df)*0.20) # Split : 20% teste + 80% treino
test_df  = df_shuffled.iloc[:limite_teste].copy()
train_df = df_shuffled.iloc[limite_teste:len(df)].copy()
X_train = train_df[FEATURES].values
y_train = le.transform(train_df[TARGET])
X_test  = test_df[FEATURES].values
y_test  = le.transform(test_df[TARGET])
print("\nTreino:", len(train_df), "| Teste:", len(test_df))
# Out:
# Treino: 126 | Teste: 31

# %%
def dist_classes(frame, target_col, titulo):
    vc = frame[target_col].value_counts(dropna=False)
    pct = (vc / len(frame) * 100).round(1)
    out = pd.DataFrame({"qtd": vc, "%": pct})
    print(f"\n=== {titulo} (n={len(frame)}) ===")
    display(out)

dist_classes(df, TARGET, "Dataset completo")
dist_classes(train_df, TARGET, "Treino")
dist_classes(test_df, TARGET, "Teste")
# Out:
# === Dataset completo (n=157) ===
#                  qtd     %
# Happiness_Class
# baixo             58  36.9
# medio             52  33.1
# alto              47  29.9
# === Treino (n=126) ===
#                  qtd     %
# Happiness_Class
# baixo             46  36.5
# medio             43  34.1
# alto              37  29.4
# === Teste (n=31) ===
#                  qtd     %
# Happiness_Class
# baixo             12  38.7
# alto              10  32.3
# medio              9  29.0

# %%
# Modelo KNN
K = 15

WEIGHTS = "distance"  # "uniform" ou "distance"

model = Pipeline(steps=[
    ("scaler", StandardScaler()),
    ("knn", KNeighborsClassifier(n_neighbors=K, weights=WEIGHTS))
])

model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('knn',
#                  KNeighborsClassifier(n_neighbors=15, weights='distance'))])

# %%
# Avaliação

y_pred = model.predict(X_test)

print("\nFeatures usadas:", FEATURES)
print("Acurácia:", accuracy_score(y_test, y_pred))
print("\nRelatório:")
print(classification_report(y_test, y_pred, target_names=le.classes_))
print("Matriz de confusão (real x previsto):")
print(confusion_matrix(y_test, y_pred))
# Out:
# Features usadas: ['Economy (GDP per Capita)', 'Health (Life Expectancy)']
# Acurácia: 0.6451612903225806
#
# Relatório:
#               precision    recall  f1-score   support
#
#         alto       0.78      0.70      0.74        10
#        baixo       0.86      0.50      0.63        12
#        medio       0.47      0.78      0.58         9
#
#     accuracy                           0.65        31
#    macro avg       0.70      0.66      0.65        31
# weighted avg       0.72      0.65      0.65        31
#
# Matriz de confusão (real x previsto):
# [[7 0 3]
#  [1 6 5]
#  [1 1 7]]

# %%
# Resultado detalhado do teste
test_df["classe_prevista"] = le.inverse_transform(y_pred)
display(test_df[["Country", "Region"] + FEATURES + [TARGET, "classe_prevista"]])
# Out:
#                 Country                           Region  \
# 0   Congo (Brazzaville)               Sub-Saharan Africa
# 1           El Salvador      Latin America and Caribbean
# 2                 Gabon               Sub-Saharan Africa
# 3           Ivory Coast               Sub-Saharan Africa
# 4                  Iraq  Middle East and Northern Africa
# 5                 Malta                   Western Europe
# 6               Vietnam                Southeastern Asia
# 7               Tunisia  Middle East and Northern Africa
# 8             Macedonia       Central and Eastern Europe
# 9              Cambodia                Southeastern Asia
# 10           Luxembourg                   Western Europe
# 11               Poland       Central and Eastern Europe
# 12              Germany                   Western Europe
# 13             Paraguay      Latin America and Caribbean
# 14               Panama      Latin America and Caribbean
# 15             Colombia      Latin America and Caribbean
# 16              Georgia       Central and Eastern Europe
# 17              Albania       Central and Eastern Europe
# 18                Syria  Middle East and Northern Africa
# 19            Mauritius               Sub-Saharan Africa
# 20                Egypt  Middle East and Northern Africa
# 21              Ireland                   Western Europe
# 22        United States                    North America
# 23               Sweden                   Western Europe
# 24               France                   Western Europe
# 25          Philippines                Southeastern Asia
# 26               Belize      Latin America and Caribbean
# 27             Bulgaria       Central and Eastern Europe
# 28               Uganda               Sub-Saharan Africa
# 29               Greece                   Western Europe
# 30               Guinea               Sub-Saharan Africa
#
#     Economy (GDP per Capita)  Health (Life Expectancy) Happiness_Class  \
# 0                    77.1090                    28.212           baixo
# 1                     8.7370                   596.000            alto
# 2                   115.8510                     3.494           baixo
# 3                    55.5070                     4.476           baixo
# 4                   107.4740                    51.076           baixo
# 5                   130.7820                    80.315            alto
# 6                    74.0370                    66.157           medio
# 7                    97.7240                    59.577           medio
# 8                     1.0193                    64.738           medio
# 9                    55.6040                    42.494           baixo
# 10                  169.7520                    84.542            alto
# 11                  124.5850                    69.058           medio
# 12                  144.7870                    81.487            alto
# 13                   89.3730                    58.295           medio
# 14                  118.3060                    70.835            alto
# 15                  103.0320                    59.659            alto
# 16                   83.7920                    64.035           baixo
# 17                    9.5530                    73.007           baixo
# 18                   74.7190                    62.994           baixo
# 19                  114.3720                    66.189           medio
# 20                   95.3950                    52.116           baixo
# 21                  148.3410                    81.455            alto
# 22                  150.7960                   779.000            alto
# 23                  145.1810                    83.121            alto
# 24                  139.4880                    83.795            alto
# 25                   81.2170                    47.036           medio
# 26                   87.6160                    45.569           medio
# 27                  111.3060                    67.806           baixo
# 28                   34.7190                    19.625           baixo
# 29                  124.8860                    80.029           medio
# 30                   22.4150                    18.829           baixo
#
#    classe_prevista
# 0            baixo
# 1             alto
# 2            medio
# 3            baixo
# 4            medio
# 5            medio
# 6            medio
# 7            medio
# 8             alto
# 9            baixo
# 10            alto
# 11           medio
# 12            alto
# 13           medio
# 14           medio
# 15           medio
# 16           baixo
# 17           medio
# 18           medio
# 19           medio
# 20           medio
# 21            alto
# 22            alto
# 23            alto
# 24            alto
# 25           baixo
# 26           medio
# 27            alto
# 28           baixo
# 29           medio
# 30           baixo

# %%
# ========= Árvore de decisão (usando as MESMAS variáveis do seu Colab) =========
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt

# "simples" e legível para aula (ajuste se quiser):
tree = DecisionTreeClassifier(
    max_depth=3,          # controla complexidade/legibilidade
    random_state=RANDOM_STATE
)

tree.fit(X_train, y_train)
y_pred_tree = tree.predict(X_test)

print("\n=== Árvore de decisão ===")
print("Features usadas:", FEATURES)
print("Acurácia:", accuracy_score(y_test, y_pred_tree))
print("\nRelatório:")
print(classification_report(y_test, y_pred_tree, target_names=le.classes_))
print("Matriz de confusão (real x previsto):")
print(confusion_matrix(y_test, y_pred_tree))

# Resultado detalhado do teste (sem mudar sua tabela do KNN, usa outra coluna)
test_df["classe_prevista_arvore"] = le.inverse_transform(y_pred_tree)
display(test_df[["Country", "Region"] + FEATURES + [TARGET, "classe_prevista_arvore"]])

# desenhar a árvore
plt.figure(figsize=(18, 10))
plot_tree(
    tree,
    feature_names=FEATURES,
    class_names=list(le.classes_),
    filled=True,
    rounded=True,
    impurity=True
)
plt.title("Árvore de Decisão (max_depth=3) — previsão de classe de temperatura")
plt.show()
# Out:
# === Árvore de decisão ===
# Features usadas: ['Economy (GDP per Capita)', 'Health (Life Expectancy)']
# Acurácia: 0.5806451612903226
#
# Relatório:
#               precision    recall  f1-score   support
#
#         alto       0.80      0.80      0.80        10
#        baixo       0.71      0.42      0.53        12
#        medio       0.36      0.56      0.43         9
#
#     accuracy                           0.58        31
#    macro avg       0.62      0.59      0.59        31
